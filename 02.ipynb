# %%
# %matplotlib inline
import math
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import FukudaCsv


# アラームログが格納されているディレクトリを指定する. 空文字を指定した場合はサンプルデータを表示します．
dir_path_to_process = ''

# CSVのロード
df = FukudaCsv.load(dir_path_to_process)

# 画像サイズを指定
figsize_ = 18, 8

df.head()
# Out:
# 記録時刻:2021-10-12 07:38:00 〜 2021-10-14 17:06:00,  2 days 09:28:00 (57時間)
#   Unnamed:0   No.                  時刻     床番号     コード      発生要因  \
# 0     44933  1798 2021-10-12 07:38:00  CH1001  0x201F  心電図ノイズ混入
# 1     44932  1799 2021-10-12 07:38:00  CH1001  0x201F  心電図ノイズ混入
# 2     44931  1800 2021-10-12 07:49:00  CH1001  0x201F  心電図ノイズ混入
# 3      4956  2983 2021-10-12 08:09:00  CH1002  0x1010    ＳｐＯ2下限
# 4     44906  1825 2021-10-12 08:11:00  CH1001  0x201F  心電図ノイズ混入
#
#                     値  継続時間       レベル  継続時間int hour    dayhour dayhour10min  \
# 0                 ---     4  N(TECH_)        4   07  10月12日07時   12日07時30分台
# 1                 ---     5  N(TECH_)        5   07  10月12日07時   12日07時30分台
# 2                 ---     3  N(TECH_)        3   07  10月12日07時   12日07時40分台
# 3  (計測値)89 < (下限閾値)90    25  H(MEAS_)       25   08  10月12日08時   12日08時00分台
# 4                 ---     8  N(TECH_)        8   08  10月12日08時   12日08時10分台
#
# ...

# %%
# 発生要因とCHのピボットテーブルを作成
pt = pd.pivot_table(df, index=['発生要因'], columns='床番号', values='コード', aggfunc=len, margins=True, fill_value=0)

# 機器情報アラーム（テクニカルアラーム）と生体情報アラーム（バイタルアラーム）の順序を整理
pt = pt.reindex(index=['SpO2コネクタ抜け', 'ＳｐＯ2センサ確認', '電極確認', '心電図ノイズ混入', '心電低振幅', 
                     '無呼吸上限', 'ＳｐＯ2下限', '心拍数上限', '心拍数下限', 'ＲＵＮ', 'ＳＬＯＷ　ＶＴ', 'ＡＳＹＳＴＯＬＥ', 'ＶＦ', 'ＶＴ', 'All'])

# 表のサイズを指定する
plt.figure(figsize=figsize_)

# 表のタイトルを指定する
plt.title('アラーム別・CH別アラーム件数')

# ピボットテーブルをヒートマップとして表示する
sns.heatmap(pt,annot=True, linewidths=.5, fmt="1.0f", cmap="PuBu",robust=True)
# Out:
# <AxesSubplot:title={'center':'アラーム別・CH別アラーム件数'}, xlabel='床番号', ylabel='発生要因'>
